# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
w=float(input("Введите массу тела: "))
x=list(range(7))
y=[w-1.5*i for i in x]
print(y)
plt.plot(x,y)
plt.show()
# Out:
# Введите массу тела: 70
# [70.0, 68.5, 67.0, 65.5, 64.0, 62.5, 61.0]
